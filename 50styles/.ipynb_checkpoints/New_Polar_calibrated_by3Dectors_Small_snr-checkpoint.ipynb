# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib inline
import glob, os
#parent_dir = './Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.13DetctorsXYZSNR1.0-2.0_source180shiftMode0-1_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt'
#for pdf_file in glob.glob(os.path.join(parent_dir )):
    #print (int(pdf_file.split('/')[-1].split('-')[-1][9:-4]))
import operator
#x = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}

w = 15
h=10
#path = '~/Downloads/GravitationalWave-master/Random_Polar_Dectors'
def Plot_train_ERROR(parent_dirs ):
    tot =[]
    for parent_dir in parent_dirs:
        dac = {}
        print os.path.join(parent_dir  )
        for file0 in glob.glob(os.path.join(parent_dir  )):
            #print file0
            ite = int(file0.split('/')[-1].split('-')[-1][9:-4]) 

            ac=[]
            ac0=[]

            with open(file0, "r") as text_file:  
                n=0
                for line in text_file:
                    #print (line.split(' '))
                    sp = line.split(' ')
                    if len(sp)>1 and n==10:
                        #print sp[2][10:]
                        ac.append(float(sp[1][10:]))
                        ac.append(float(sp[2][10:]))


                    n+=1
            #mac = np.min(ac)
            #mac0 = np.min(ac0)
            #ind = ac0.index(mac0)
            dac[ite] =ac 
        sorted_x = sorted(dac.items(), key=operator.itemgetter(0))
        #print sorted_x    
        u=29
        s =8
        e = -4
        y = [u[1][0] for u in sorted_x]
        x = [u[0]  for u in sorted_x]
        tot.append((x,y))
        
    #labels = [ key.split('_')[-1] for key in dac.keys()]
    #y= [dac[files[0]][:u],dac[files[1]][:u],dac[files[2]][:u]]
    #labels = [files[0][b:e], files[1][b:e], files[2][b:e]]
    fig =plt.figure(figsize=(w,h))
    #labels = ['Theta_XY', 'XYZ','XYZ1', '4Detectors','5Dectors']
    #labels = [ '5Detectors_smallSNR','5Detectors_smallSNR2','5Detectors',]
    labels = ['3Detectors-LHV','4Detectors-LHVI','4Detectors-LHVK','5Detectors-LHVKI']
    for z,label in  zip(tot,labels):
    #    x = [100*x for x in range(len(y_arr))]
        plt.plot(z[0][3:], z[1][3:],label=label)
    #plt.plot(x, z, label='Old')
    plt.legend( fontsize=30)
    plt.xlabel('Iterations', fontsize=30)
    plt.ylabel('RMSE ', fontsize=30)
    #plt.title('Sigma plot', fontsize=30)
    #plt.show()   
    plt.savefig('./RMSE_vs_Iterations_RandomPolar_with_Detectors.pdf')
    
    
files = [ './Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.13DetctorsXYZSNR1.0-2.0_source180shiftMode0-1_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt'
, './Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.14Detct-ICT-XYZSNR1.0-2.0_source180shiftMode0-2_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt',
          './Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.14DetctorsXYZSNR1.0-2.0_source180shiftMode0-1_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt',
         './Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.15DetctorsXYZSNR1.0-2.0_source180shiftMode0-1_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt'
]  

Plot_train_ERROR( files)
# Out:
# ./Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.13DetctorsXYZSNR1.0-2.0_source180shiftMode0-1_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt
# ./Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.14Detct-ICT-XYZSNR1.0-2.0_source180shiftMode0-2_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt
# ./Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.14DetctorsXYZSNR1.0-2.0_source180shiftMode0-1_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt
# ./Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.15DetctorsXYZSNR1.0-2.0_source180shiftMode0-1_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib inline
import glob, os
#parent_dir = './Random_Polar_Dectors/CovMap_RandomPolarL2LossRatio0.13DetctorsXYZSNR1.0-2.0_source180shiftMode0-1_GaussianOneMirror_epoch3000withAncillary54Weight0.006_lr9e-05_epoch900000_testL21.0-900000_newnet-iteration*.txt'
#for pdf_file in glob.glob(os.path.join(parent_dir )):
    #print (int(pdf_file.split('/')[-1].split('-')[-1][9:-4]))
import operator
#x = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}

w = 15
h=10
#path = '~/Downloads/GravitationalWave-master/Random_Polar_Dectors'
def Plot_train_ERROR(parent_dirs ):
    tot =[]
    for parent_dir in parent_dirs:
        dac = {}
        print os.path.join(parent_dir  )
        for file0 in glob.glob(os.path.join(parent_dir  )):
            #print file0
            ite = int(file0.split('/')[-1].split('-')[-1][9:-4]) 

            ac=[]
            ac0=[]

            with open(file0, "r") as text_file:  
                n=0
                for line in text_file:
                    #print (line.split(' '))
                    sp = line.split(' ')
                    if len(sp)>1 and n==10:
                        print sp[1][10:]
                        ac.append(float(sp[1][10:]))
                        ac.append(float(sp[2][10:]))


                    n+=1
            #mac = np.min(ac)
            #mac0 = np.min(ac0)
            #ind = ac0.index(mac0)
            dac[ite] =ac 
        sorted_x = sorted(dac.items(), key=operator.itemgetter(0))
        #print sorted_x    
        u=29
        s =8
        e = -4
        y = [u[1][0] for u in sorted_x]
        x = [u[0]  for u in sorted_x]
        tot.append((x,y))
        
    #labels = [ key.split('_')[-1] for key in dac.keys()]
    #y= [dac[files[0]][:u],dac[files[1]][:u],dac[files[2]][:u]]
    #labels = [files[0][b:e], files[1][b:e], files[2][b:e]]
    fig =plt.figure(figsize=(w,h))
    #labels = ['Theta_XY', 'XYZ','XYZ1', '4Detectors','5Dectors']
    #labels = [ '5Detectors_smallSNR','5Detectors_smallSNR2','5Detectors',]
    labels = ['4Detectors-LHVI']
    for z,label in  zip(tot,labels):
    #    x = [100*x for x in range(len(y_arr))]
        plt.plot(z[0][3:], z[1][3:],label=label)
    #plt.plot(x, z, label='Old')
    plt.legend( fontsize=30)
    plt.xlabel('Iterations', fontsize=30)
    plt.ylabel('RMSE ', fontsize=30)
    #plt.title('Sigma plot', fontsize=30)
    #plt.show()   
    plt.savefig('./RMSE_vs_Iterations_RandomPolar_with_Detectors.pdf')
    
    
files = [ #'./NEW_Mean_By3Detectors/RandPolarL2LossRatio0.14Detct-ICT-XYZscaledSNR0.1-0.2_souc180shiftMode0-2_Gaussian_epoch3000Ancil54Weight0.006_lr9e-05_epoch1600000_testL20.1-1600000_newnet-iteration*.txt',
#'./NEW_Mean_By3Detectors/RandPolarL2LossRatio0.14Detct-KAR-XYZscaledSNR0.1-0.2_souc180shiftMode0-2_Gaussian_epoch3000Ancil54Weight0.006_lr9e-05_epoch1600000_testL20.1-1600000_newnet-iteration*.txt',
    './NEW_Mean_By3Detectors/RandPolarL2LossRatio0.15DectsXYZscaledSNR0.1-0.2_sorc180shiftMod0-0new7_Gaussian_epoch3000Ancil54Weight0.006_lr9e-05_epoch1600000_testL20.1-1600000_newnet-iteration*.txt',
        ]

Plot_train_ERROR( files)
# Out:
# ./NEW_Mean_By3Detectors/RandPolarL2LossRatio0.15DectsXYZscaledSNR0.1-0.2_sorc180shiftMod0-0new7_Gaussian_epoch3000Ancil54Weight0.006_lr9e-05_epoch1600000_testL20.1-1600000_newnet-iteration*.txt
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# 0.25640869140625
# ...
